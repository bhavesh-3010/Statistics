# %% [markdown]
# # Statistics

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
#      Hypothesis testing in statistics is a method used to make inferences about a population based on sample data by testing an assumption, called the null hypothesis (H₀), which typically states that there is no effect or difference. An alternative hypothesis (H₁) represents what you aim to support. Using a test statistic calculated from the sample, you determine the likelihood (p-value) of observing the data if H₀ is true. If the p-value is less than a predetermined significance level (commonly 0.05), you reject H₀, suggesting there is enough evidence to support H₁. Otherwise, you fail to reject H₀, meaning the data doesn’t provide strong enough evidence against it.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis
#
#      - The null hypothesis (H₀) is a statement that assumes there is no effect, no difference, or no relationship between variables—it represents the default or status quo assumption in a hypothesis test. In contrast, the alternative hypothesis (H₁ or Ha) is what you aim to prove; it suggests that there is an effect, a difference, or a relationship. The null hypothesis is tested directly, and based on the evidence from the sample data, it is either rejected in favor of the alternative hypothesis or not rejected if the data does not provide strong enough support.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important?
#
#       - The significance level, denoted by alpha (α), is the threshold used in hypothesis testing to decide whether to reject the null hypothesis. It represents the probability of making a **Type I error**, which is rejecting the null hypothesis when it is actually true. Common values for α are 0.05, 0.01, or 0.10. The significance level is important because it sets the standard for how strong the evidence must be to conclude that the observed effect is real and not due to random chance. Choosing an appropriate α helps balance the risks of making incorrect conclusions in statistical decision-making.

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing?
#
#      - In hypothesis testing, a **p-value** represents the probability of obtaining the observed results, or more extreme ones, assuming that the **null hypothesis is true**. It measures the strength of evidence against the null hypothesis: the smaller the p-value, the stronger the evidence to reject H₀. If the p-value is less than or equal to the chosen significance level (e.g., 0.05), you reject the null hypothesis, suggesting that the observed effect is statistically significant. A large p-value means the data is consistent with H₀, and there is not enough evidence to support the alternative hypothesis.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing
#
#       - To interpret the p-value in hypothesis testing, compare it to the chosen significance level (α), usually 0.05. If the **p-value is less than or equal to α**, it means the observed results are unlikely to have occurred by random chance under the null hypothesis, so you **reject the null hypothesis** and conclude there is statistically significant evidence for the alternative hypothesis. If the **p-value is greater than α**, you **fail to reject the null hypothesis**, meaning there isn’t enough evidence to support the alternative, and the results could be due to chance. The smaller the p-value, the stronger the evidence against the null hypothesis.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
#   - A Type 1 error occurs when the null hypothesis (H₀) is true, but you wrongly reject it—this is also known as a "false positive." A Type 2 error happens when the null hypothesis is false, but you fail to reject it—called a "false negative." Type 1 errors are controlled by the significance level (α), while Type 2 errors are related to the test’s power. Balancing both is essential to minimize wrong conclusions in hypothesis testing.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#   - A one-tailed test checks for an effect in only one direction (either greater than or less than), while a two-tailed test checks for effects in both directions (not equal to). One-tailed tests are more powerful in detecting a specific direction of change, but two-tailed tests are used when the direction of the effect is not known or when deviations in both directions are important.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing?
#   - A Z-test is used to determine whether there is a significant difference between sample and population means when the population standard deviation is known and the sample size is large. It assumes the data is normally distributed and is often used for large-scale data analysis or when population parameters are available.

# %% [markdown]
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#   - The Z-score is calculated using the formula:
#
# 𝑍
# =
# 𝑥
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# x
# ˉ
#  −μ
# ​
#
#   - It represents how many standard deviations a sample mean is from the population mean. In hypothesis testing, it helps determine how extreme the sample data is under the null hypothesis, which in turn helps calculate the p-value and make decisions about rejecting the null.

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#   - The T-distribution is used when the sample size is small (typically less than 30) and/or the population standard deviation is unknown. It is similar to the normal distribution but has heavier tails to account for greater variability. It provides more accurate results in small-sample hypothesis testing.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test?
#   - A Z-test is used when the population standard deviation is known and the sample size is large, while a T-test is used when the standard deviation is unknown and/or the sample size is small. Z-tests use the standard normal distribution; T-tests use the t-distribution, which adjusts for extra uncertainty in small samples.

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing?
#   - A T-test is used to compare means and determine if they are significantly different. It is used when the population standard deviation is unknown. Types include one-sample, two-sample (independent), and paired-sample t-tests, and they are used based on whether you're comparing one group, two independent groups, or two related groups.

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#   - Both Z-tests and T-tests assess whether differences between means are statistically significant. The key difference lies in sample size and knowledge of population standard deviation. As sample size increases, the t-distribution approaches the normal distribution, and results from both tests become nearly identical.

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#   - A confidence interval (CI) is a range of values derived from sample data that is likely to contain the true population parameter with a specified level of confidence (e.g., 95%). It provides an estimate of uncertainty around a sample statistic. A narrower interval indicates more precision, while a wider one suggests more uncertainty.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval?
#   - The margin of error is the amount added to and subtracted from the sample statistic to create a confidence interval. It reflects the maximum expected difference between the true population parameter and the sample estimate. A larger margin results in a wider confidence interval, indicating more uncertainty in the estimate.

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#   - Bayes' Theorem is used to update the probability of a hypothesis based on new evidence. It combines prior probability with the likelihood of observed data to produce a revised (posterior) probability. It is significant in decision-making processes under uncertainty and widely used in fields like medicine, machine learning, and economics.

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used?
#   - The Chi-square distribution is a skewed distribution used in tests involving categorical data, such as goodness-of-fit tests and tests of independence. It is based on the sum of squared standard normal variables and is only defined for non-negative values. Its shape depends on degrees of freedom.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#   - The Chi-square goodness of fit test assesses whether observed categorical data matches expected distributions. It is applied by comparing observed frequencies to expected ones under a given hypothesis. If the calculated chi-square statistic exceeds the critical value, the null hypothesis (that the data fits the distribution) is rejected.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#   - The F-distribution is used in tests that compare two or more sample variances, such as in ANOVA and regression analysis. It is positively skewed and defined only for positive values. The shape depends on two sets of degrees of freedom. A large F-value indicates greater differences between group variances or model fits.

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions?
#   - ANOVA (Analysis of Variance) is used to compare the means of three or more groups to determine if at least one group mean differs significantly. Its assumptions include: independence of observations, normality of residuals, and equal variances across groups. If assumptions are violated, the results may not be valid.

# %% [markdown]
# 21. What are the different types of ANOVA tests?
#   - The main types of ANOVA tests are:
#     - One-way ANOVA: compares means across one factor.
#     - Two-way ANOVA: examines effects of two factors and their interaction.
#     - Repeated Measures ANOVA: compares means across multiple time points or conditions within the same subjects.
#   - Each type is suited to different experimental designs.

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing?
#   - The F-test is a statistical test that compares the ratio of two variances to determine if they are significantly different. It is used in ANOVA and regression to test whether groups have equal variances or whether a model explains a significant portion of variance. A high F-value relative to the critical value leads to rejection of the null hypothesis.

# %% [markdown]
# #Practical

# %%
#1Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results

import numpy as np
from scipy import stats

# Sample data
sample = [52, 55, 49, 51, 50, 53, 48, 54, 56, 50]  # Sample data
population_mean = 50  # Known population mean
population_std = 3    # Known population standard deviation (σ)
alpha = 0.05          # Significance level

# Calculate sample statistics
sample_mean = np.mean(sample)
n = len(sample)
standard_error = population_std / np.sqrt(n)

# Calculate Z-score
z_score = (sample_mean - population_mean) / standard_error

# Calculate P-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Interpretation
print(f"Sample Mean: {sample_mean}")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Result: Reject the null hypothesis. The sample mean is significantly different from the population mean.")
else:
    print("Result: Fail to reject the null hypothesis. No significant difference between the sample and population mean.")
# Out:
# Sample Mean: 51.8
# Z-score: 1.8974
# P-value: 0.0578
# Result: Fail to reject the null hypothesis. No significant difference between the sample and population mean.

# %%
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

import numpy as np
from scipy import stats

# Simulate random sample data (e.g., test scores)
np.random.seed(42)  # For reproducibility
sample = np.random.normal(loc=51, scale=5, size=30)  # Mean=51, std=5, n=30

# Define population mean for hypothesis testing
population_mean = 50
alpha = 0.05  # Significance level

# Perform one-sample T-test
t_statistic, p_value = stats.ttest_1samp(sample, population_mean)

# Display results
print(f"Sample Mean: {np.mean(sample):.2f}")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
if p_value < alpha:
    print("Result: Reject the null hypothesis. The sample mean is significantly different from the population mean.")
else:
    print("Result: Fail to reject the null hypothesis. No significant difference between the sample and population mean.")
# Out:
# Sample Mean: 50.06
# T-statistic: 0.0721
# P-value: 0.9430
# Result: Fail to reject the null hypothesis. No significant difference between the sample and population mean.

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean

import numpy as np
from scipy.stats import norm

# Simulated sample data
sample = [102, 98, 101, 100, 99, 97, 103, 104, 96, 100]
population_mean = 100    # Known population mean
population_std = 3       # Known population standard deviation (σ)
alpha = 0.05             # Significance level

# Calculate sample statistics
sample_mean = np.mean(sample)
n = len(sample)
standard_error = population_std / np.sqrt(n)

# Calculate Z-score
z_score = (sample_mean - population_mean) / standard_error

# Two-tailed test: Calculate P-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Output results
print(f"Sample Mean: {sample_mean}")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
if p_value < alpha:
    print("Result: Reject the null hypothesis. Sample mean is significantly different from population mean.")
else:
    print("Result: Fail to reject the null hypothesis. No significant difference between sample and population mean.")
# Out:
# Sample Mean: 100.0
# Z-score: 0.0000
# P-value: 1.0000
# Result: Fail to reject the null hypothesis. No significant difference between sample and population mean.

# %%
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample and population details
sample = [102, 98, 101, 100, 99, 97, 103, 104, 96, 100]
population_mean = 100
population_std = 3
alpha = 0.05

# Z-test calculations
sample_mean = np.mean(sample)
n = len(sample)
standard_error = population_std / np.sqrt(n)
z_score = (sample_mean - population_mean) / standard_error
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Print Z-test results
print(f"Sample Mean: {sample_mean}")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")
if p_value < alpha:
    print("Result: Reject the null hypothesis.")
else:
    print("Result: Fail to reject the null hypothesis.")

# Visualization of the decision region
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

# Critical Z values for two-tailed test
z_critical = norm.ppf(1 - alpha/2)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')

# Shade rejection regions
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.5, label='Rejection Region')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.5)

# Plot the Z-score
plt.axvline(z_score, color='black', linestyle='--', linewidth=2, label=f'Z-score = {z_score:.2f}')
plt.axvline(-z_critical, color='green', linestyle=':', linewidth=2, label=f'Z-critical = ±{z_critical:.2f}')
plt.axvline(z_critical, color='green', linestyle=':', linewidth=2)

# Labels and legend
plt.title("Two-tailed Z-test Visualization")
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Sample Mean: 100.0
# Z-score: 0.0000
# P-value: 1.0000
# Result: Fail to reject the null hypothesis.

# %%
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0=100, mu1=102, sigma=3, n=30, alpha=0.05):
    """
    Visualize Type I and Type II errors for a two-tailed Z-test.
    mu0: Mean under the null hypothesis
    mu1: Mean under the alternative hypothesis
    sigma: Standard deviation of population
    n: Sample size
    alpha: Significance level
    """
    se = sigma / np.sqrt(n)
    x = np.linspace(mu0 - 4*sigma, mu1 + 4*sigma, 1000)

    # Null and alternative distributions
    y_null = norm.pdf(x, mu0, se)
    y_alt = norm.pdf(x, mu1, se)

    # Critical values for rejection region (two-tailed)
    z_crit = norm.ppf(1 - alpha/2)
    lower_crit = mu0 - z_crit * se
    upper_crit = mu0 + z_crit * se

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.plot(x, y_null, label='Null Hypothesis (H₀)', color='blue')
    plt.plot(x, y_alt, label='Alternative Hypothesis (H₁)', color='green')

    # Shade Type I error (alpha)
    plt.fill_between(x, y_null, where=(x < lower_crit) | (x > upper_crit), color='red', alpha=0.3, label='Type I Error (α)')

    # Shade Type II error (beta)
    plt.fill_between(x, y_alt, where=(x >= lower_crit) & (x <= upper_crit), color='orange', alpha=0.3, label='Type II Error (β)')

    # Vertical lines
    plt.axvline(lower_crit, color='black', linestyle='--', label=f'Lower Critical Value: {lower_crit:.2f}')
    plt.axvline(upper_crit, color='black', linestyle='--', label=f'Upper Critical Value: {upper_crit:.2f}')

    # Labels and legend
    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function to visualize
visualize_type1_type2_errors()

# %%
# 6. Write a Python program to perform an independent T-test and interpret the results

import numpy as np
from scipy import stats

# Simulated data for two independent groups (e.g., Group A and Group B)
group_a = [55, 60, 62, 58, 57, 61, 59, 56, 60, 58]
group_b = [52, 54, 53, 50, 51, 55, 52, 54, 53, 52]

# Perform independent T-test (assumes equal variance by default)
t_stat, p_value = stats.ttest_ind(group_a, group_b)

# Output results
print("Group A Mean:", np.mean(group_a))
print("Group B Mean:", np.mean(group_b))
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis. There is a significant difference between the two group means.")
else:
    print("Result: Fail to reject the null hypothesis. No significant difference between the two group means.")
# Out:
# Group A Mean: 58.6
# Group B Mean: 52.6
# T-statistic: 7.0711
# P-value: 0.0000
# Result: Reject the null hypothesis. There is a significant difference between the two group means.

# %%
# 7. Perform a paired sample T-test using Python and visualize the comparison results

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Simulated paired data (e.g., before and after a treatment)
before = [72, 75, 78, 74, 73, 77, 76, 74, 75, 72]
after =  [70, 73, 76, 72, 71, 75, 74, 72, 73, 70]

# Perform paired T-test
t_stat, p_value = ttest_rel(before, after)

# Output results
print("Mean (Before):", np.mean(before))
print("Mean (After):", np.mean(after))
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis. There is a significant difference between the paired samples.")
else:
    print("Result: Fail to reject the null hypothesis. No significant difference between the paired samples.")

# Visualization
x = np.arange(len(before))
plt.figure(figsize=(10, 5))
plt.plot(x, before, marker='o', label='Before', color='blue')
plt.plot(x, after, marker='o', label='After', color='green')
plt.title('Paired Sample Comparison (Before vs After)')
plt.xlabel('Sample Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean (Before): 74.6
# Mean (After): 72.6
# T-statistic: inf
# P-value: 0.0000
# Result: Reject the null hypothesis. There is a significant difference between the paired samples.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python

import numpy as np
from scipy.stats import ttest_1samp, norm

# Simulate sample data
np.random.seed(42)
sample = np.random.normal(loc=52, scale=5, size=30)  # Sample from N(52, 5)
population_mean = 50
population_std = 5  # Assumed known for Z-test
alpha = 0.05

# --- Z-Test ---
sample_mean = np.mean(sample)
n = len(sample)
se_z = population_std / np.sqrt(n)
z_score = (sample_mean - population_mean) / se_z
p_value_z = 2 * (1 - norm.cdf(abs(z_score)))

# --- T-Test ---
t_stat, p_value_t = ttest_1samp(sample, population_mean)

# Output comparison
print(f"Sample Mean: {sample_mean:.2f}")
print(f"\nZ-test:\n  Z-score = {z_score:.4f}\n  P-value = {p_value_z:.4f}")
print(f"T-test:\n  T-statistic = {t_stat:.4f}\n  P-value = {p_value_t:.4f}")

# Interpretation
if p_value_z < alpha:
    print("\nZ-test result: Reject the null hypothesis.")
else:
    print("\nZ-test result: Fail to reject the null hypothesis.")

if p_value_t < alpha:
    print("T-test result: Reject the null hypothesis.")
else:
    print("T-test result: Fail to reject the null hypothesis.")
# Out:
# Sample Mean: 51.06
#
# Z-test:
#   Z-score = 1.1604
#   P-value = 0.2459
# T-test:
#   T-statistic = 1.2893
#   P-value = 0.2075
#
# Z-test result: Fail to reject the null hypothesis.
# T-test result: Fail to reject the null hypothesis.

# %%
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance

import numpy as np
from scipy.stats import t

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean using the t-distribution.

    Parameters:
        data (list or array): Sample data
        confidence (float): Confidence level (default 0.95 for 95%)

    Returns:
        Tuple (lower_bound, upper_bound)
    """
    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    se = sample_std / np.sqrt(n)
    t_critical = t.ppf((1 + confidence) / 2, df=n - 1)

    margin_of_error = t_critical * se
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return (lower_bound, upper_bound)

# Example usage
sample = [10, 12, 13, 11, 14, 12, 13, 15, 10, 11]
ci = confidence_interval(sample, confidence=0.95)
print(f"95% Confidence Interval: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# 95% Confidence Interval: 10.91 to 13.29

# %%
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data

import numpy as np
from scipy import stats

def margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.

    Parameters:
        data (list or np.array): Sample data
        confidence (float): Confidence level (default 0.95 for 95%)

    Returns:
        Margin of error (float)
    """
    data = np.array(data)
    n = len(data)
    se = stats.sem(data)  # Standard error of the mean
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)  # t critical value

    moe = t_crit * se
    return round(moe, 3)

# Example usage
sample_data = [52, 55, 53, 50, 54, 56, 52, 53, 55, 51]
confidence = 0.95
moe = margin_of_error(sample_data, confidence)

print("Sample Mean:", np.mean(sample_data))
print(f"{int(confidence*100)}% Margin of Error:", moe)
# Out:
# Sample Mean: 53.1
# 95% Margin of Error: 1.368

# %%
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

def bayes_theorem(prior, sensitivity, specificity):
    """
    Calculate the posterior probability using Bayes' Theorem.

    Parameters:
        prior (float): P(Disease) — prior probability of having the disease
        sensitivity (float): P(Positive | Disease) — true positive rate
        specificity (float): P(Negative | No Disease) — true negative rate

    Returns:
        posterior (float): P(Disease | Positive) — probability of disease given a positive test
    """
    # Complement values
    p_disease = prior
    p_no_disease = 1 - prior
    p_pos_given_disease = sensitivity
    p_pos_given_no_disease = 1 - specificity

    # Total probability of a positive test
    p_positive = (p_pos_given_disease * p_disease) + (p_pos_given_no_disease * p_no_disease)

    # Bayes' Theorem
    posterior = (p_pos_given_disease * p_disease) / p_positive
    return round(posterior, 4)

# Example scenario
prior = 0.01           # 1% of population has the disease
sensitivity = 0.95     # 95% true positive rate
specificity = 0.98     # 98% true negative rate

posterior = bayes_theorem(prior, sensitivity, specificity)
print(f"Probability of having the disease given a positive test result: {posterior * 100:.2f}%")
# Out:
# Probability of having the disease given a positive test result: 32.42%

# %%
# 12. Perform a Chi-square test for independence between two categorical variables in Python

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Simulated survey data: Gender vs Preferred Product
data = {'Product A': [20, 15],
        'Product B': [30, 35],
        'Product C': [25, 20]}
index = ['Male', 'Female']

# Create a contingency table
contingency_table = pd.DataFrame(data, index=index)

# Perform Chi-square test of independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print results
print("Contingency Table:")
print(contingency_table, '\n')
print(f"Chi-square Statistic: {chi2:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p:.4f}\n")

# Interpret the result
alpha = 0.05
if p < alpha:
    print("Result: Reject the null hypothesis — the variables are dependent (not independent).")
else:
    print("Result: Fail to reject the null hypothesis — no evidence of dependency between the variables.")
# Out:
# Contingency Table:
#         Product A  Product B  Product C
# Male           20         30         25
# Female         15         35         20
#
# Chi-square Statistic: 1.4838
# Degrees of Freedom: 2
# P-value: 0.4762
#
# Result: Fail to reject the null hypothesis — no evidence of dependency between the variables.

# %%
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Observed frequency data (e.g., gender vs choice)
observed_data = pd.DataFrame({
    'Choice A': [30, 20],
    'Choice B': [10, 40]
}, index=['Male', 'Female'])

# Display observed data
print("Observed Frequencies:")
print(observed_data, "\n")

# Calculate expected frequencies using chi2_contingency (but only use the expected part)
chi2, p, dof, expected = chi2_contingency(observed_data)

# Convert expected frequencies to a DataFrame for better display
expected_df = pd.DataFrame(expected, index=observed_data.index, columns=observed_data.columns)

# Display expected frequencies
print("Expected Frequencies (if variables are independent):")
print(expected_df.round(2))
# Out:
# Observed Frequencies:
#         Choice A  Choice B
# Male          30        10
# Female        20        40
#
# Expected Frequencies (if variables are independent):
#         Choice A  Choice B
# Male        20.0      20.0
# Female      30.0      30.0

# %%
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

import numpy as np
from scipy.stats import chisquare

# Observed frequencies (e.g., from a dice roll experiment)
observed = np.array([18, 22, 20, 17, 19, 24])  # 6 categories (like die faces)

# Expected frequencies (e.g., fair die → uniform distribution)
expected = np.array([20] * 6)  # All outcomes equally likely

# Perform the chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Output results
print("Observed Frequencies:", observed)
print("Expected Frequencies:", expected)
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject the null hypothesis — the data does not follow the expected distribution.")
else:
    print("\nResult: Fail to reject the null hypothesis — no significant difference from the expected distribution.")
# Out:
# Observed Frequencies: [18 22 20 17 19 24]
# Expected Frequencies: [20 20 20 20 20 20]
#
# Chi-square Statistic: 1.7000
# P-value: 0.8889
#
# Result: Fail to reject the null hypothesis — no significant difference from the expected distribution.

# %%
# 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Parameters
df_list = [1, 2, 5, 10]  # Different degrees of freedom
x = np.linspace(0, 30, 500)

# Plot the Chi-square distributions
plt.figure(figsize=(10, 6))
for df in df_list:
    plt.plot(x, chi2.pdf(x, df), label=f'df = {df}')

plt.title("Chi-square Distribution for Different Degrees of Freedom")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 16. Implement an F-test using Python to compare the variances of two random samples

import numpy as np
from scipy.stats import f

# Generate two random samples
np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=10, size=30)
sample2 = np.random.normal(loc=50, scale=15, size=30)

# Calculate variances
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# Perform the F-test (larger variance / smaller variance)
f_stat = var1 / var2 if var1 > var2 else var2 / var1
df1 = len(sample1) - 1
df2 = len(sample2) - 1

# Calculate p-value (two-tailed)
p_value = 2 * min(f.cdf(f_stat, df1, df2), 1 - f.cdf(f_stat, df1, df2))

# Output results
print("Sample 1 Variance:", round(var1, 2))
print("Sample 2 Variance:", round(var2, 2))
print("F-statistic:", round(f_stat, 4))
print("Degrees of Freedom:", df1, "and", df2)
print("P-value:", round(p_value, 4))

# Interpret result
alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject the null hypothesis — the variances are significantly different.")
else:
    print("\nResult: Fail to reject the null hypothesis — no significant difference in variances.")
# Out:
# Sample 1 Variance: 81.0
# Sample 2 Variance: 195.06
# F-statistic: 2.4082
# Degrees of Freedom: 29 and 29
# P-value: 0.0209
#
# Result: Reject the null hypothesis — the variances are significantly different.

# %%
# 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results

import numpy as np
from scipy.stats import f_oneway

# Simulate data for 3 groups (e.g., test scores for different teaching methods)
np.random.seed(42)
group1 = np.random.normal(loc=70, scale=5, size=30)  # Group A
group2 = np.random.normal(loc=75, scale=5, size=30)  # Group B
group3 = np.random.normal(loc=80, scale=5, size=30)  # Group C

# Perform one-way ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)

# Print the results
print("F-statistic:", round(f_stat, 4))
print("P-value:", round(p_value, 4))

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject the null hypothesis — at least one group mean is significantly different.")
else:
    print("\nResult: Fail to reject the null hypothesis — no significant difference in group means.")
# Out:
# F-statistic: 40.9756
# P-value: 0.0
#
# Result: Reject the null hypothesis — at least one group mean is significantly different.

# %%
# 18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import f_oneway
import seaborn as sns

# Simulate data for 3 groups
np.random.seed(42)
group_A = np.random.normal(loc=68, scale=4, size=30)
group_B = np.random.normal(loc=72, scale=4, size=30)
group_C = np.random.normal(loc=75, scale=4, size=30)

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Score': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A'] * 30 + ['B'] * 30 + ['C'] * 30
})

# Perform one-way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Print ANOVA results
print("F-statistic:", round(f_stat, 4))
print("P-value:", round(p_value, 4))

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject the null hypothesis — at least one group mean is significantly different.")
else:
    print("\nResult: Fail to reject the null hypothesis — no significant difference in group means.")

# Plotting the group comparisons using boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Score', data=data, palette='Set2')
plt.title('Group Score Comparison using One-Way ANOVA')
plt.xlabel('Group')
plt.ylabel('Score')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# F-statistic: 32.2804
# P-value: 0.0
#
# Result: Reject the null hypothesis — at least one group mean is significantly different.
# <ipython-input-18-575433e5a07a>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Score', data=data, palette='Set2')

# %%
# 19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy.stats import shapiro, levene
from statsmodels.stats.stattools import durbin_watson

def check_anova_assumptions(data, group_col, value_col):
    """
    Check ANOVA assumptions: Normality, Homogeneity of variance, Independence.

    Parameters:
    - data: Pandas DataFrame with grouped data
    - group_col: Name of the column indicating group
    - value_col: Name of the column with numerical values

    Returns:
    - Prints test statistics and p-values for assumptions
    """
    # Split into groups
    groups = [group[value_col].values for name, group in data.groupby(group_col)]

    # 1. Normality (Shapiro-Wilk on residuals)
    model = sm.formula.ols(f"{value_col} ~ C({group_col})", data=data).fit()
    residuals = model.resid
    stat, p_normal = shapiro(residuals)
    print("1. Shapiro-Wilk Normality Test:")
    print(f"   Statistic = {stat:.4f}, p-value = {p_normal:.4f}")
    print("   " + ("Residuals are normal ✅" if p_normal > 0.05 else "Residuals are NOT normal ❌"))

    # 2. Homogeneity of variance (Levene’s test)
    stat, p_levene = levene(*groups)
    print("\n2. Levene's Test for Equal Variances:")
    print(f"   Statistic = {stat:.4f}, p-value = {p_levene:.4f}")
    print("   " + ("Variances are equal ✅" if p_levene > 0.05 else "Variances are NOT equal ❌"))

    # 3. Independence (Durbin-Watson on residuals)
    dw_stat = durbin_watson(residuals)
    print("\n3. Durbin-Watson Test for Independence:")
    print(f"   Statistic = {dw_stat:.4f}")
    if 1.5 < dw_stat < 2.5:
        print("   Residuals are independent ✅")
    else:
        print("   Residuals may not be independent ❌")

# Example usage with simulated data
if __name__ == "__main__":
    np.random.seed(42)
    df = pd.DataFrame({
        'Group': ['A']*30 + ['B']*30 + ['C']*30,
        'Score': np.concatenate([
            np.random.normal(70, 5, 30),
            np.random.normal(72, 5, 30),
            np.random.normal(75, 5, 30)
        ])
    })

    check_anova_assumptions(df, 'Group', 'Score')
# Out:
# 1. Shapiro-Wilk Normality Test:
#    Statistic = 0.9925, p-value = 0.8948
#    Residuals are normal ✅
#
# 2. Levene's Test for Equal Variances:
#    Statistic = 0.1480, p-value = 0.8627
#    Variances are equal ✅
#
# 3. Durbin-Watson Test for Independence:
#    Statistic = 2.0560
#    Residuals are independent ✅

# %%
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Simulate data: Study effect of 'Treatment' and 'Gender' on 'Score'
np.random.seed(42)
n = 20

treatments = ['A', 'B']
genders = ['Male', 'Female']
data = []

for treatment in treatments:
    for gender in genders:
        # Simulate some interaction effect
        base = 70 if treatment == 'A' else 75
        gender_effect = 3 if gender == 'Female' else 0
        scores = np.random.normal(loc=base + gender_effect, scale=4, size=n)
        for score in scores:
            data.append([treatment, gender, score])

# Create DataFrame
df = pd.DataFrame(data, columns=['Treatment', 'Gender', 'Score'])

# Two-way ANOVA with interaction
model = ols('Score ~ C(Treatment) + C(Gender) + C(Treatment):C(Gender)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Print results
print("Two-Way ANOVA Results:\n")
print(anova_table)

# Interpretation
print("\nInterpretation:")
for factor in anova_table.index:
    p = anova_table.loc[factor, "PR(>F)"]
    if p < 0.05:
        print(f" - {factor}: Significant effect (p = {p:.4f}) ✅")
    else:
        print(f" - {factor}: No significant effect (p = {p:.4f}) ❌")

# Visualization
plt.figure(figsize=(8, 6))
sns.pointplot(x='Treatment', y='Score', hue='Gender', data=df, dodge=True, capsize=0.1, errwidth=1.5)
plt.title("Interaction Plot: Treatment × Gender")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Two-Way ANOVA Results:
#
#                              sum_sq    df          F        PR(>F)
# C(Treatment)             663.177306   1.0  43.985638  4.294058e-09
# C(Gender)                156.938297   1.0  10.409028  1.850730e-03
# C(Treatment):C(Gender)     0.647573   1.0   0.042951  8.363724e-01
# Residual                1145.862093  76.0        NaN           NaN
#
# Interpretation:
#  - C(Treatment): Significant effect (p = 0.0000) ✅
#  - C(Gender): Significant effect (p = 0.0019) ✅
#  - C(Treatment):C(Gender): No significant effect (p = 0.8364) ❌
#  - Residual: No significant effect (p = nan) ❌
# <ipython-input-20-1d08cf24fc73>:49: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   sns.pointplot(x='Treatment', y='Score', hue='Gender', data=df, dodge=True, capsize=0.1, errwidth=1.5)

# %%
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Degrees of freedom
df1 = 5  # numerator
df2 = 20  # denominator

# Create an array of F-values
x = np.linspace(0, 5, 500)
y = f.pdf(x, df1, df2)

# Plot the F-distribution
plt.figure(figsize=(8, 5))
plt.plot(x, y, 'b-', label=f'F-distribution (df1={df1}, df2={df2})')
plt.fill_between(x[x > f.ppf(0.95, df1, df2)], y[x > f.ppf(0.95, df1, df2)], color='red', alpha=0.3, label='Rejection Region (α = 0.05)')
plt.axvline(f.ppf(0.95, df1, df2), color='red', linestyle='--')

plt.title('F-Distribution Curve')
plt.xlabel('F-value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Simulate data for 3 groups
np.random.seed(0)
group1 = np.random.normal(loc=70, scale=5, size=30)
group2 = np.random.normal(loc=75, scale=5, size=30)
group3 = np.random.normal(loc=80, scale=5, size=30)

# Combine into a DataFrame
df = pd.DataFrame({
    'Score': np.concatenate([group1, group2, group3]),
    'Group': ['Group 1']*30 + ['Group 2']*30 + ['Group 3']*30
})

# Perform one-way ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)

# Print results
print("One-Way ANOVA Results:")
print(f"F-statistic = {f_stat:.4f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis – at least one group mean is significantly different.")
else:
    print("Result: Fail to reject the null hypothesis – no significant difference in group means.")

# Boxplot visualization
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Score', data=df, palette='pastel')
plt.title('Group Means Comparison using One-Way ANOVA')
plt.ylabel('Score')
plt.xlabel('Group')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# One-Way ANOVA Results:
# F-statistic = 17.2958
# P-value = 0.0000
# Result: Reject the null hypothesis – at least one group mean is significantly different.
# <ipython-input-22-7f3e2ae8c4c1>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Score', data=df, palette='pastel')

# %%
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# Simulate two normal distributions
np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=5, size=100)  # mean=50
sample2 = np.random.normal(loc=52, scale=5, size=100)  # mean=52

# Perform independent t-test
t_stat, p_value = ttest_ind(sample1, sample2)

# Print results
print("Independent T-Test Results:")
print(f"T-statistic = {t_stat:.4f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis – the means are significantly different.")
else:
    print("Result: Fail to reject the null hypothesis – no significant difference in means.")

# Visualize the distributions
plt.figure(figsize=(8, 5))
sns.kdeplot(sample1, label="Sample 1 (mean=50)", fill=True)
sns.kdeplot(sample2, label="Sample 2 (mean=52)", fill=True)
plt.axvline(np.mean(sample1), color='blue', linestyle='--')
plt.axvline(np.mean(sample2), color='orange', linestyle='--')
plt.title("Comparison of Two Simulated Normal Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Independent T-Test Results:
# T-statistic = -3.9953
# P-value = 0.0001
# Result: Reject the null hypothesis – the means are significantly different.

# %%
# 24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

import numpy as np
from scipy.stats import chi2

# Sample data
np.random.seed(42)
sample = np.random.normal(loc=100, scale=10, size=30)  # true std dev = 10
sample_size = len(sample)
sample_variance = np.var(sample, ddof=1)

# Known population variance (hypothesized)
pop_variance = 100  # std dev = 10

# Chi-square test statistic
chi2_stat = (sample_size - 1) * sample_variance / pop_variance

# Degrees of freedom
df = sample_size - 1

# Significance level
alpha = 0.05

# Critical values (two-tailed test)
chi2_critical_low = chi2.ppf(alpha / 2, df)
chi2_critical_high = chi2.ppf(1 - alpha / 2, df)

# Print test results
print("Chi-Square Test for Population Variance")
print(f"Sample Variance = {sample_variance:.2f}")
print(f"Chi-Square Statistic = {chi2_stat:.2f}")
print(f"Chi-Square Critical Values (α = {alpha}): [{chi2_critical_low:.2f}, {chi2_critical_high:.2f}]")

# Decision
if chi2_stat < chi2_critical_low or chi2_stat > chi2_critical_high:
    print("Result: Reject the null hypothesis – sample variance significantly differs from population variance.")
else:
    print("Result: Fail to reject the null hypothesis – no significant difference in variance.")
# Out:
# Chi-Square Test for Population Variance
# Sample Variance = 81.00
# Chi-Square Statistic = 23.49
# Chi-Square Critical Values (α = 0.05): [16.05, 45.72]
# Result: Fail to reject the null hypothesis – no significant difference in variance.

# %%
# 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# Example: Suppose we are comparing success rates between two groups
# Group 1: 60 successes out of 100 trials
# Group 2: 45 successes out of 90 trials

successes = np.array([60, 45])
samples = np.array([100, 90])

# Perform two-proportion Z-test
z_stat, p_value = proportions_ztest(successes, samples)

# Print results
print("Z-Test for Two Proportions")
print(f"Z-statistic = {z_stat:.4f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis – proportions are significantly different.")
else:
    print("Result: Fail to reject the null hypothesis – no significant difference in proportions.")
# Out:
# Z-Test for Two Proportions
# Z-statistic = 1.3842
# P-value = 0.1663
# Result: Fail to reject the null hypothesis – no significant difference in proportions.

# %%
# 26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Simulate two datasets
np.random.seed(42)
data1 = np.random.normal(loc=0, scale=5, size=50)
data2 = np.random.normal(loc=0, scale=8, size=50)

# Calculate sample variances
var1 = np.var(data1, ddof=1)
var2 = np.var(data2, ddof=1)

# F-test statistic (larger variance / smaller variance)
f_stat = var2 / var1 if var2 > var1 else var1 / var2

# Degrees of freedom
df1 = len(data1) - 1
df2 = len(data2) - 1

# Significance level
alpha = 0.05

# Critical values
f_crit_low = f.ppf(alpha / 2, df1, df2)
f_crit_high = f.ppf(1 - alpha / 2, df1, df2)

# Print test results
print("F-Test for Comparing Variances")
print(f"Variance 1 = {var1:.4f}")
print(f"Variance 2 = {var2:.4f}")
print(f"F-statistic = {f_stat:.4f}")
print(f"Critical values (α = {alpha}): [{f_crit_low:.4f}, {f_crit_high:.4f}]")

# Interpretation
if f_stat < f_crit_low or f_stat > f_crit_high:
    print("Result: Reject the null hypothesis – variances are significantly different.")
else:
    print("Result: Fail to reject the null hypothesis – no significant difference in variances.")

# Visualization
x = np.linspace(0.1, 5, 500)
y = f.pdf(x, df1, df2)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='F-distribution', color='blue')
plt.axvline(f_stat, color='red', linestyle='--', label='F-statistic')
plt.axvline(f_crit_low, color='green', linestyle='--', label='Lower critical value')
plt.axvline(f_crit_high, color='green', linestyle='--', label='Upper critical value')
plt.fill_between(x, y, where=(x < f_crit_low) | (x > f_crit_high), color='orange', alpha=0.3, label='Rejection regions')
plt.title('F-Test for Comparing Variances')
plt.xlabel('F-value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# F-Test for Comparing Variances
# Variance 1 = 21.7934
# Variance 2 = 48.9244
# F-statistic = 2.2449
# Critical values (α = 0.05): [0.5675, 1.7622]
# Result: Reject the null hypothesis – variances are significantly different.

# %%
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results

import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

# Simulated observed data (e.g., categories A–D)
observed = np.array([50, 30, 15, 5])

# Expected frequencies under uniform distribution
expected = np.array([25, 25, 25, 25])  # Null: each category has equal chance

# Perform Chi-square goodness of fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Print results
print("Chi-Square Goodness of Fit Test")
print(f"Observed: {observed}")
print(f"Expected: {expected}")
print(f"Chi-square Statistic = {chi2_stat:.4f}")
print(f"P-value = {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis – the observed distribution does not fit the expected distribution.")
else:
    print("Result: Fail to reject the null hypothesis – the observed distribution fits the expected distribution.")

# Visualization
categories = ['A', 'B', 'C', 'D']
x = np.arange(len(categories))

plt.figure(figsize=(8, 5))
bar_width = 0.35
plt.bar(x - bar_width/2, observed, bar_width, label='Observed', color='skyblue')
plt.bar(x + bar_width/2, expected, bar_width, label='Expected', color='orange')
plt.xticks(x, categories)
plt.title('Chi-Square Goodness of Fit Test')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Chi-Square Goodness of Fit Test
# Observed: [50 30 15  5]
# Expected: [25 25 25 25]
# Chi-square Statistic = 46.0000
# P-value = 0.0000
# Result: Reject the null hypothesis – the observed distribution does not fit the expected distribution.
